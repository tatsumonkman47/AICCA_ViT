# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


"""
Tensorboard not working remotely unfortunetly :P


os.environ['TENSORBOARD_BINARY'] = '/home/tdmonkman/anaconda3/envs/please_work/bin/tensorboard'

# Load tensorboard extension
# %load_ext tensorboard

# Opens tensorboard in notebook. Adjust the path to your CHECKPOINT_PATH! Feel free to change "ResNet" to "ResNetPreAct"
# %tensorboard --logdir /home/tdmonkman/scratch-midway2/AICCA_proj/ViT_wide/lightning_logs/ 

"""

print("welcome")
# Out:
# welcome

# %%
os.environ['TENSORBOARD_BINARY'] = '/home/tdmonkman/anaconda3/envs/please_work/bin/tensorboard'

# %%
model_dirs_output = ["ViT_1M_3layer",
                     "ViT_1M_1layers_64patches",
                     "ViT_1M_2layer_256patches",
                     "ViT_1M_2layers_64patches",
                     "ViT_1M_3layer_64patches",
                    ]
save_matrix = {}

for output_dir in model_dirs_output:
    versions = os.listdir(f"./{output_dir}/lightning_logs/")
    save_matrix[output_dir]=[pd.read_csv(f"./{output_dir}/lightning_logs/{version}/metrics.csv") for version in versions]

# %%
val_mask = np.isfinite(save_matrix["ViT_1M_1layers_64patches"][0].val_acc)
val_step_masked = save_matrix["ViT_1M_1layers_64patches"][0].step[val_mask]

# %%
val_step_masked
# Out:
# 111     5531
# 224    11063
# 336    16595
# 449    22127
# 562    27659
# 674    33191
# 787    38723
# Name: step, dtype: int64

# %%
plt.figure(figsize=(20,10))

plt.plot(save_matrix["ViT_1M_1layers_64patches"][0].step,save_matrix["ViT_1M_1layers_64patches"][0].train_acc,label="ViT_1M_1layer 64 patches train_acc",color="steelblue",alpha=0.7)
plt.plot(save_matrix["ViT_1M_2layer_256patches"][0].step,save_matrix["ViT_1M_2layer_256patches"][0].train_acc,label="ViT_1M_2layer 256 patches train_acc",color="indianred",alpha=0.7)


val_mask = np.isfinite(save_matrix["ViT_1M_2layer_256patches"][0].val_acc)
val_step_masked = save_matrix["ViT_1M_2layer_256patches"][0].step[val_mask]
val_acc_masked = save_matrix["ViT_1M_2layer_256patches"][0].val_acc[val_mask]
plt.plot(val_step_masked,val_acc_masked,color="indianred",linestyle="--",linewidth=4)
plt.scatter(val_step_masked,val_acc_masked,color="k",s=250,zorder=8)
plt.scatter(val_step_masked,val_acc_masked,label="ViT_1M_2layer_256patches val_acc",color="indianred",s=150,zorder=9)

val_mask = np.isfinite(save_matrix["ViT_1M_1layers_64patches"][0].val_acc)
val_step_masked = save_matrix["ViT_1M_1layers_64patches"][0].step[val_mask]
val_acc_masked = save_matrix["ViT_1M_1layers_64patches"][0].val_acc[val_mask]
plt.plot(val_step_masked,val_acc_masked,color="steelblue",linestyle="--",linewidth=4)
plt.scatter(val_step_masked,val_acc_masked,color="k",s=250,zorder=10)
plt.scatter(val_step_masked,val_acc_masked,label="ViT_1M_1layer val_acc",color="steelblue",s=150,zorder=11)


plt.legend()

plt.xlabel("Step",fontsize=25)
plt.xlabel("Accuracy",fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
# Out:
# (array([-5000.,     0.,  5000., 10000., 15000., 20000., 25000., 30000.,
#         35000., 40000., 45000.]),
#  [Text(-5000.0, 0, '−5000'),
#   Text(0.0, 0, '0'),
#   Text(5000.0, 0, '5000'),
#   Text(10000.0, 0, '10000'),
#   Text(15000.0, 0, '15000'),
#   Text(20000.0, 0, '20000'),
#   Text(25000.0, 0, '25000'),
#   Text(30000.0, 0, '30000'),
#   Text(35000.0, 0, '35000'),
#   Text(40000.0, 0, '40000'),
#   Text(45000.0, 0, '45000')])

# %%
plt.figure(figsize=(20,10))

plt.plot(save_matrix["ViT_1M_3layer_64patches"][0].step,save_matrix["ViT_1M_3layer_64patches"][0].train_acc,label="ViT_1M_3laye 64 patches train_acc",color="indianred",alpha=0.7)
plt.plot(save_matrix["ViT_1M_2layers_64patches"][0].step,save_matrix["ViT_1M_2layers_64patches"][0].train_acc,label="ViT_1M_2layers 64 patches train_acc",color="steelblue",alpha=0.7)


val_mask = np.isfinite(save_matrix["ViT_1M_3layer_64patches"][0].val_acc)
val_step_masked = save_matrix["ViT_1M_3layer_64patches"][0].step[val_mask]
val_acc_masked = save_matrix["ViT_1M_3layer_64patches"][0].val_acc[val_mask]
plt.plot(val_step_masked,val_acc_masked,color="indianred",linestyle="--",linewidth=4)
plt.scatter(val_step_masked,val_acc_masked,color="k",s=250,zorder=8)
plt.scatter(val_step_masked,val_acc_masked,label="ViT_1M_3layer_64patches val_acc",color="indianred",s=150,zorder=9)

val_mask = np.isfinite(save_matrix["ViT_1M_2layers_64patches"][0].val_acc)
val_step_masked = save_matrix["ViT_1M_2layers_64patches"][0].step[val_mask]
val_acc_masked = save_matrix["ViT_1M_2layers_64patches"][0].val_acc[val_mask]
plt.plot(val_step_masked,val_acc_masked,color="steelblue",linestyle="--",linewidth=4)
plt.scatter(val_step_masked,val_acc_masked,color="k",s=250,zorder=10)
plt.scatter(val_step_masked,val_acc_masked,label="ViT_1M_2layers_64patches val_acc",color="steelblue",s=150,zorder=11)


plt.legend()

plt.xlabel("Step",fontsize=25)
plt.xlabel("Accuracy",fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
   
    
    
    
    
    
plt.plot(save_matrix["ViT_1M_2layer_256patches"][0].step,save_matrix["ViT_1M_2layer_256patches"][0].train_acc,label="ViT_1M_2layer 256 patches train_acc",color="orange",alpha=0.7)
plt.plot(save_matrix["ViT_1M_1layers_64patches"][0].step,save_matrix["ViT_1M_1layers_64patches"][0].train_acc,label="ViT_1M_1layer 64 patches train_acc",color="blue",alpha=0.7)


val_mask = np.isfinite(save_matrix["ViT_1M_2layer_256patches"][0].val_acc)
val_step_masked = save_matrix["ViT_1M_2layer_256patches"][0].step[val_mask]
val_acc_masked = save_matrix["ViT_1M_2layer_256patches"][0].val_acc[val_mask]
plt.plot(val_step_masked,val_acc_masked,color="orange",linestyle="--",linewidth=4)
plt.scatter(val_step_masked,val_acc_masked,color="k",s=250,zorder=8)
plt.scatter(val_step_masked,val_acc_masked,label="ViT_1M_2layer_256patches val_acc",color="orange",s=150,zorder=9)

val_mask = np.isfinite(save_matrix["ViT_1M_1layers_64patches"][0].val_acc)
val_step_masked = save_matrix["ViT_1M_1layers_64patches"][0].step[val_mask]
val_acc_masked = save_matrix["ViT_1M_1layers_64patches"][0].val_acc[val_mask]
plt.plot(val_step_masked,val_acc_masked,color="blue",linestyle="--",linewidth=4)
plt.scatter(val_step_masked,val_acc_masked,color="k",s=250,zorder=10)
plt.scatter(val_step_masked,val_acc_masked,label="ViT_1M_1layer val_acc",color="blue",s=150,zorder=11)


plt.legend()

plt.xlabel("Step",fontsize=25)
plt.xlabel("Accuracy",fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
    
    
plt.grid()
